# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/LICENSE.txt
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_50.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_9.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_46.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_90.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_121.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_55.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_4.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_91.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_38.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_128.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_83.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_116.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_7.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_51.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_117.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_104.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_81.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_67.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_39.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_118.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_120.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_107.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_35.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_43.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_0.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_31.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_8.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_59.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_109.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_6.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_40.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_112.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_105.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_92.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_78.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_125.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_19.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_16.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_93.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_76.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_25.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_94.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_61.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_32.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_89.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_102.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_53.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_73.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_101.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_30.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_17.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_66.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_34.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_84.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_64.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_75.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_63.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_111.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_49.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_80.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_12.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_110.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_68.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_27.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_72.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_56.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_22.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_44.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_15.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_87.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_20.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_127.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_23.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_113.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_77.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_54.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_108.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_18.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_11.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_95.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_69.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_36.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_26.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_28.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_99.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_5.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_48.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_21.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_42.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_52.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_13.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_29.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_119.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_129.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_41.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_14.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_88.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_33.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_57.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_45.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_24.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_114.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_126.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_74.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_122.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_71.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_1.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_98.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_58.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_10.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_65.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_2.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_123.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_47.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_62.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_70.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_115.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_106.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_60.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_37.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_82.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_79.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/liver_3.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_50.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_9.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_46.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_90.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_121.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_55.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_4.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_91.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_38.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_128.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_83.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_116.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_7.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_51.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_117.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_104.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_81.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_67.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_39.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_118.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_120.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_107.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_35.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_43.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_0.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_31.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_8.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_59.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_109.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_6.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_40.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_112.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_105.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_92.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_78.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_125.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_19.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_16.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_93.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_76.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_25.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_94.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_61.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_32.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_89.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_102.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_53.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_73.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_101.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_30.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_17.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_66.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_34.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_84.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_64.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_75.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_63.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_111.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_49.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_80.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_12.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_110.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_68.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_27.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_72.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_56.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_22.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_44.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_15.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_87.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_20.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_127.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_23.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_113.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_77.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_54.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_108.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_18.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_11.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_95.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_69.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_36.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_26.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_28.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_99.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_5.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_48.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_21.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_42.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_52.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_13.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_29.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_119.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_129.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_41.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_14.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_88.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_33.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_57.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_45.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_24.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_114.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_126.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_74.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_122.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_71.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_1.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_98.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_58.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_10.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_65.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_2.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_123.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_47.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_62.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_70.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_115.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_106.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_60.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_37.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_82.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_79.nii
# /kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/liver_3.nii

# %%
# !pip install monai
# Out:
# Collecting monai
#   Downloading monai-1.3.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: torch>=1.9 in /opt/conda/lib/python3.10/site-packages (from monai) (2.1.2)
# Requirement already satisfied: numpy>=1.20 in /opt/conda/lib/python3.10/site-packages (from monai) (1.26.4)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.9->monai) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.9->monai) (1.3.0)
# Downloading monai-1.3.1-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 29.3 MB/s eta 0:00:00
# Installing collected packages: monai
# Successfully installed monai-1.3.1

# %% [markdown]
# # **Загрузка данных**

# %%
from glob import glob

#Создаем массивы images и labels, куда закидываем из путей все изображения с форматом .nii
images_nii = sorted(glob(f"/kaggle/input/3d-liver-segmentation/Task03_Liver_rs/imagesTr/*.nii"))
labels_nii = sorted(glob(f"/kaggle/input/3d-liver-segmentation/Task03_Liver_rs/labelsTr/*.nii"))

# %% [markdown]
# # **Обработка изображений *.nii и их визуализация**

# %%
import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt

def get_transpose(image,label,x=0,y=1,z=2):
    return image.transpose(x,y,z), label.transpose(x,y,z)

def get_slices_nii(images,labels,n=None):
    images_slices = list()
    labels_slices = list()
    
    if not n or n > len(images):
        n = len(images)
    
    
    for i, (im_nii, l_nii) in enumerate(zip(images, labels)):
        if i < n:
            image_nii = nib.load(im_nii).get_fdata()
            label_nii = nib.load(l_nii).get_fdata()

            image_nii,label_nii  = get_transpose(image_nii,label_nii,2,1,0)

            # ранее был использован enumerate
            for im, l in zip(image_nii, label_nii):
                if len(np.unique(l)) == 2:
                    images_slices.append(im.astype('float32'))
                    labels_slices.append(l.astype('float32'))
    
    return images_slices, labels_slices
    
def preprocessing_nii(images):
    for i in range(len(images)):
        images[i][images[i] < 0] = 0
        images[i] = images[i]/np.max(images[i])
        
    # Можно добавить и для labels, но так как изначально мы выбираем только те метки где есть только два класса для каждого пикселя, то можно не делать этого
#     for i in range(len(labels)):
#         labels[i][labels[i] > 1] = 1
    
    return images
                
def get_visualization(image,label):
    fig, axes = plt.subplots(1, 2, figsize=(8, 3))

    axes[0].imshow((image * 255).astype('uint8') * 255, cmap='gray')
    axes[0].set_title('Изображение')
    axes[0].axis('off')

    axes[1].imshow(label, cmap='gray')
    axes[1].set_title('Маска')
    axes[1].axis('off')

# %%
ims, ls = get_slices_nii(images_nii,labels_nii,123) 
ims = preprocessing_nii(ims)

# %% [markdown]
# Посмотрим на минимальные и максимальные значения в изображениях и их меток

# %%
print('Image')
print(f'Min value: {np.min(ims[0])}; Max value: {np.max(ims[0])}')
print()
print('Label')
print(f'Min value: {np.min(ls[0])}; Max value: {np.max(ls[0])}')
# Out:
# Image
# Min value: 0.0; Max value: 1.0
#
# Label
# Min value: 0.0; Max value: 1.0

# %%
# import random

# Перешивает данные, чтобы можно было увидеть разные варианты изображений и их меток
# def shuffle_slices(images,labels):    
#     combined = list(zip(images,labels))

#     random.shuffle(combined)

#     images_shuffled, labels_shuffled = zip(*combined)

#     return images_shuffled, labels_shuffled

# %% [markdown]
# Функция выше закомментрирована, чтобы мы в дальнейшем смогли сравнить первые 10 изображений до обработки с помощью аугментаций и после нее

# %%
# ims_shuffle, ls_shuffle = shuffle_slices(ims,ls)
for i ,(im,l) in enumerate(zip(ims,ls)):
    if i < 10:
        get_visualization(im,l)

# %% [markdown]
# # **Обработка с помощью аугментации**

# %%
import albumentations as A
from albumentations.pytorch import ToTensorV2

def preprocessing_data(images, labels):
    # Определение аугментаций для изображений и масок
    data_transforms = A.Compose([
        A.Resize(256, 256),  # Изменение размера до 256x256 пикселей
        A.HorizontalFlip(),  # Горизонтальное отражение
        A.VerticalFlip(),    # Вертикальное отражение
        A.Rotate(limit=30),  # Поворот на случайный угол до ±30 градусов
        ToTensorV2()  # Преобразование в тензор PyTorch
    ])

    # Применение аугментаций к изображению
    
    images_transfromed = list()
    labels_transformed = list()
    
    for im,l in zip(images,labels):
        data_transformed = data_transforms(image=im,mask=l)
        
        im_transformed = data_transformed['image']
        l_transformed = data_transformed['mask']
        
        im_transformed = im_transformed.float()
        l_transformed = l_transformed.unsqueeze(0).float()
        
        images_transfromed.append(im_transformed)
        labels_transformed.append(l_transformed)
        
    
    return images_transfromed, labels_transformed

# %%
ims_transformed, ls_transformed =  preprocessing_data(ims,ls)

# %%
ims_transformed[0].shape
# Out:
# torch.Size([1, 256, 256])

# %%
# Визуализация тензоров изображений и их меток
def get_visualization_tensor(image,label):
    fig, axes = plt.subplots(1, 2, figsize=(8, 3))

    axes[0].imshow((image * 255).squeeze(0).numpy().astype('uint8') * 255, cmap='gray')
    axes[0].set_title('Изображение')
#     axes[0].axis('off')

    axes[1].imshow(label.squeeze(0), cmap='gray')
    axes[1].set_title('Маска')
#     axes[1].axis('off')

# %%
for i ,(im,l) in enumerate(zip(ims_transformed,ls_transformed)):
    if i < 10:
        get_visualization_tensor(im,l)

# %% [markdown]
# # **Преобразование данных в датасет**

# %%
import torch
from torch.utils.data import Dataset, DataLoader, random_split

# Используем Dataset для создания пользовательского датасета CustomDataset, далее обернем его в DataLoader

class CustomDataset(Dataset):
    def __init__(self, images, labels):
        self.images = images
        self.labels = labels

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.images[idx]
        label = self.labels[idx]
        return image, label


custom_dataset = CustomDataset(ims_transformed, ls_transformed)


train_size = int(0.6 * len(custom_dataset))
val_size = int(0.2 * len(custom_dataset))
test_size = len(custom_dataset) - train_size - val_size

train_ds, val_ds, test_ds = random_split(custom_dataset, [train_size,val_size,test_size])

batch_size = 8

train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True, drop_last=True)

val_loader = DataLoader(val_ds, batch_size=batch_size, shuffle=False, drop_last=True)

test_loader = DataLoader(test_ds, batch_size=batch_size, shuffle=False, drop_last=True)

# %%
print(f'Train(тренировочный) объём данных: {len(train_loader)}')
print(f'Val(валидационный) объём данных: {len(val_loader)}')
print(f'Test(тестовый) объём данных: {len(test_loader)}')
# Out:
# Train(тренировочный) объём данных: 318
# Val(валидационный) объём данных: 106
# Test(тестовый) объём данных: 106

# %% [markdown]
# # **Индекс Жакара**

# %%
# def get_iou(outputs, labels):
#     outputs = torch.sigmoid(outputs) > 0.5
#     outputs = outputs.squeeze(1).byte()
#     labels = labels.squeeze(1).byte()
#     eps = 1e-8
#     intersection = (outputs & labels).float().sum((1, 2))
#     union = (outputs | labels).float().sum((1, 2))
    
#     iou = (intersection + eps) / (union + eps)

#     return torch.mean(iou).item()


def get_iou(out,labels):
    eps = 1e-8
    out = torch.sigmoid(out) > 0.9
    out = out.squeeze(1)
    labels = labels.squeeze(1)
    intersection = torch.logical_and(out, labels).sum().float()
    union = torch.logical_or(out, labels).sum().float()
    
    iou = (intersection + eps) / (union + eps)
    return iou.mean().item()

# %% [markdown]
# # **Тренировка**

# %%
if torch.cuda.is_available():
    print('CUDA доступен. Вычисления будут производиться на GPU.')
else:
    print('CUDA недоступен. Вычисления будут производиться на CPU.')
# Out:
# CUDA доступен. Вычисления будут производиться на GPU.

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# Ипользуем коллбэки для сохранения моделей

# %%
import torch

class BestModelCheckpointCallback:
    def __init__(self, model, filepath, monitor='iou_val', mode='min'):
        self.model = model
        self.filepath = filepath
        self.monitor = monitor
        self.mode = mode
        self.best_metric = float('inf') if mode == 'min' else float('-inf')

    def __call__(self, metric, name_model):
        if (self.mode == 'min' and metric < self.best_metric) or (self.mode == 'max' and metric > self.best_metric):
            self.best_metric = metric
            torch.save(self.model.state_dict(), self.filepath.format(name_model))
            print(f"Model saved with {self.monitor}: {metric}")

# Определение пути для сохранения наилучшей модели
filepath = 'best_model_{}.pth'

# %%
def train(model,train_dl,val_dl,num_epochs, loss_fn, optimizer, name_model, use_scheduler=False, access_key=True):    
    model = model.to(device)
    
    if use_scheduler:
        scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[num_epochs//2, num_epochs//1.4, num_epochs//1.2], gamma=0.2)
    
    history = {'epochs loss train':[],'epochs loss val':[],'iou(Jaccard index) train':[],'iou(Jaccard index) val':[]}
    
    best_model_callback = BestModelCheckpointCallback(model, filepath, monitor='iou_val', mode='max')
    
    for epoch in range(num_epochs):
        epoch_loss_train = 0
        epoch_loss_val = 0
        iou_batches_val = []
        iou_batches_train = []
              
        model.train()
        for batch in train_dl:
            images, labels = batch
            images, labels = images.to(device), labels.to(device)
        
            optimizer.zero_grad()
            
            if access_key:
                output = model(images)['out']
            else:
                output = model(images)

            loss_train = loss_fn(output, labels)
            loss_train.backward()
            
            optimizer.step()
            
            epoch_loss_train += loss_train.item()
            
            iou = get_iou(output,labels)
            iou_batches_train.append(iou)
        
        avg_iou_epoch_train = sum(iou_batches_train)/len(iou_batches_train)
        
        if use_scheduler:
            scheduler.step()
        
        model.eval()
                 
        for batch in val_dl:  
            images, labels = batch
            images, labels = images.to(device), labels
            
            with torch.no_grad():
                if access_key:
                    out = model(images)['out'].detach().cpu()
                else:
                    out = model(images).detach().cpu()
                
                loss_val = loss_fn(out, labels)
                epoch_loss_val += loss_val.item()
            
            iou = get_iou(out,labels)
            
            iou_batches_val.append(iou)
        
        avg_iou_epoch_val = sum(iou_batches_val)/len(iou_batches_val)
        
        best_model_callback(avg_iou_epoch_val, name_model)
        
        history['epochs loss train'].append(epoch_loss_train/len(train_dl))
        history['epochs loss val'].append(epoch_loss_val/len(val_dl))
        history['iou(Jaccard index) train'].append(avg_iou_epoch_train)
        history['iou(Jaccard index) val'].append(avg_iou_epoch_val)
        
        print(f'Epoch {epoch+1}/{num_epochs}')
        print('------------')
        print(f'Loss train: {epoch_loss_train/len(train_dl):.4f}')
        print(f'Loss val: {epoch_loss_val/len(val_dl):.4f}')
        print(f'Iou(Jaccard index) train: {avg_iou_epoch_train:.4f}')
        print(f'Iou(Jaccard index) val: {avg_iou_epoch_val:.4f}')
        print('------------')
        
    return history

# %% [markdown]
# # **Модель на основе архитектуры U-Net (собственная реализация)**

# %%
import torch.nn as nn

moment = 0.1

# Определение блока свертки для пути умешьшения размерности (Convolution Block)
class ConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(ConvBlock, self).__init__()
        
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3,stride=1,padding = 1),
            nn.BatchNorm2d(out_channels, momentum= moment),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3,stride=1,padding = 1),
            nn.BatchNorm2d(out_channels, momentum= moment),
            nn.ReLU(inplace=True),
        )
    
    def forward(self, x):
        return self.conv(x)
    
# Определение блока свертки для пути увеличения размерности (Convolution Block Up) 
class ConvBlockUp(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(ConvBlockUp, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3,stride=1,padding = 1),
            nn.BatchNorm2d(out_channels, momentum= moment),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels//2, kernel_size=3,stride=1,padding = 1),
            nn.BatchNorm2d(out_channels//2, momentum= moment),
            nn.ReLU(inplace=True),
        )
    
    def forward(self, x):
        return self.conv(x)

# Определение U-Net модели
class UNet(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(UNet, self).__init__()
        
        self.enc0 = ConvBlock(in_channels,64)
        self.maxpool0 = nn.MaxPool2d(kernel_size=2)
        
        self.enc1 = ConvBlock(64,128)
        self.maxpool1 = nn.MaxPool2d(kernel_size=2)
        
        self.enc2 = ConvBlock(128,256)
        self.maxpool2 = nn.MaxPool2d(kernel_size=2)
        
        self.enc3 = ConvBlock(256,512)
        self.maxpool3 = nn.MaxPool2d(kernel_size=2)
        
        self.bottleneck = nn.Sequential(
            nn.Conv2d(512, 1024, kernel_size=3,stride=1, padding = 1),  
            nn.BatchNorm2d(1024, momentum= moment),
            nn.ReLU(),
            nn.Conv2d(1024, 512, kernel_size=3,stride=1, padding = 1),
            nn.BatchNorm2d(512, momentum= moment),
            nn.ReLU()
        ) 
        
        self.upsample0 = nn.Upsample(scale_factor=2)
        self.dec0 = ConvBlockUp(1024,512)
        
        self.upsample1 = nn.Upsample(scale_factor=2)
        self.dec1 = ConvBlockUp(512,256)
        
        self.upsample2 = nn.Upsample(scale_factor=2)
        self.dec2 = ConvBlockUp(256,128)
        
        self.upsample3 = nn.Upsample(scale_factor=2)
        self.dec3 = nn.Sequential(
            nn.Conv2d(128, 64, kernel_size=3,stride=1,padding = 1),
            nn.BatchNorm2d(64, momentum= moment),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3,stride=1,padding = 1),
            nn.BatchNorm2d(64, momentum= moment),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, out_channels, kernel_size=1,stride=1)
        )

    def forward(self, x):
        
        enc0 = self.enc0(x)
        maxpool0 = self.maxpool0(enc0)
        
        enc1 = self.enc1(maxpool0)
        maxpool1 = self.maxpool1(enc1)
        
        enc2 = self.enc2(maxpool1)
        maxpool2 = self.maxpool2(enc2)
               
        enc3 = self.enc3(maxpool2)
        maxpool3 = self.maxpool3(enc3)
        
        bottleneck = self.bottleneck(maxpool3)
        
        dec0 = self.upsample0(bottleneck)
        dec0 = self.dec0(torch.cat((dec0,enc3), dim =1))
        
        dec1 = self.upsample1(dec0)
        dec1 = self.dec1(torch.cat((dec1,enc2), dim =1))
        
        dec2 = self.upsample2(dec1)
        dec2 = self.dec2(torch.cat((dec2,enc1), dim =1))
        
        dec3 = self.upsample3(dec2)
        dec3 = self.dec3(torch.cat((dec3,enc0), dim =1))
        
        return {'out': dec3}

# %%
import torch.optim as optim

# Определение модели
model_unet = UNet(in_channels=1, out_channels=1)

# Определение функции потерь и оптимизатора
loss_fn = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model_unet.parameters(), lr=0.001)

# Обучение модели
history_unet = train(model = model_unet,train_dl=train_loader,val_dl=val_loader,num_epochs=30,loss_fn=loss_fn,optimizer=optimizer, name_model='U-Net', use_scheduler=True)
# Out:
# Model saved with iou_val: 0.34921075825421866
# Epoch 1/30
# ------------
# Loss train: 0.1129
# Loss val: 0.0479
# Iou(Jaccard index) train: 0.3431
# Iou(Jaccard index) val: 0.3492
# ------------
# Model saved with iou_val: 0.3665356933367702
# Epoch 2/30
# ------------
# Loss train: 0.0483
# Loss val: 0.0425
# Iou(Jaccard index) train: 0.5021
# Iou(Jaccard index) val: 0.3665
# ------------
# Model saved with iou_val: 0.5982940944860566
# Epoch 3/30
# ------------
# Loss train: 0.0379
# Loss val: 0.0339
# Iou(Jaccard index) train: 0.5840
# Iou(Jaccard index) val: 0.5983
# ------------
# Epoch 4/30
# ------------
# Loss train: 0.0339
# Loss val: 0.0954
# Iou(Jaccard index) train: 0.6474
# Iou(Jaccard index) val: 0.0385
# ------------
# Model saved with iou_val: 0.6261745249887682
# Epoch 5/30
# ------------
# Loss train: 0.0352
# Loss val: 0.0286
# Iou(Jaccard index) train: 0.6199
# Iou(Jaccard index) val: 0.6262
# ------------
# Model saved with iou_val: 0.7920348447448803
# Epoch 6/30
# ------------
# Loss train: 0.0295
# Loss val: 0.0283
# Iou(Jaccard index) train: 0.6777
# Iou(Jaccard index) val: 0.7920
# ------------
# Epoch 7/30
# ------------
# Loss train: 0.0255
# Loss val: 0.0237
# Iou(Jaccard index) train: 0.7268
# Iou(Jaccard index) val: 0.7366
# ------------
# Epoch 8/30
# ------------
# Loss train: 0.0238
# Loss val: 0.0238
# Iou(Jaccard index) train: 0.7421
# Iou(Jaccard index) val: 0.7336
# ------------
# Epoch 9/30
# ------------
# Loss train: 0.0245
# Loss val: 0.0246
# Iou(Jaccard index) train: 0.7365
# Iou(Jaccard index) val: 0.7290
# ------------
# Epoch 10/30
# ------------
# Loss train: 0.0214
# Loss val: 0.0236
# Iou(Jaccard index) train: 0.7715
# Iou(Jaccard index) val: 0.7631
# ------------
# Epoch 11/30
# ------------
# Loss train: 0.0205
# Loss val: 0.0214
# Iou(Jaccard index) train: 0.7759
# Iou(Jaccard index) val: 0.7873
# ------------
# Model saved with iou_val: 0.8023799157367563
# Epoch 12/30
# ------------
# Loss train: 0.0215
# Loss val: 0.0198
# Iou(Jaccard index) train: 0.7711
# Iou(Jaccard index) val: 0.8024
# ------------
# Epoch 13/30
# ------------
# Loss train: 0.0184
# Loss val: 0.0197
# Iou(Jaccard index) train: 0.7985
# Iou(Jaccard index) val: 0.7977
# ------------
# Epoch 14/30
# ------------
# Loss train: 0.0175
# Loss val: 0.0209
# Iou(Jaccard index) train: 0.8087
# Iou(Jaccard index) val: 0.7660
# ------------
# Epoch 15/30
# ------------
# Loss train: 0.0181
# Loss val: 0.0193
# Iou(Jaccard index) train: 0.7987
# Iou(Jaccard index) val: 0.7977
# ------------
# Model saved with iou_val: 0.8316958855907872
# Epoch 16/30
# ------------
# Loss train: 0.0143
# Loss val: 0.0165
# Iou(Jaccard index) train: 0.8419
# Iou(Jaccard index) val: 0.8317
# ------------
# Model saved with iou_val: 0.8347694131563295
# Epoch 17/30
# ------------
# Loss train: 0.0133
# Loss val: 0.0163
# Iou(Jaccard index) train: 0.8496
# Iou(Jaccard index) val: 0.8348
# ------------
# Epoch 18/30
# ------------
# Loss train: 0.0129
# Loss val: 0.0163
# Iou(Jaccard index) train: 0.8557
# Iou(Jaccard index) val: 0.8324
# ------------
# Model saved with iou_val: 0.8383866379845817
# Epoch 19/30
# ------------
# Loss train: 0.0125
# Loss val: 0.0165
# Iou(Jaccard index) train: 0.8589
# Iou(Jaccard index) val: 0.8384
# ------------
# Epoch 20/30
# ------------
# Loss train: 0.0123
# Loss val: 0.0169
# Iou(Jaccard index) train: 0.8589
# Iou(Jaccard index) val: 0.8353
# ------------
# Epoch 21/30
# ------------
# Loss train: 0.0119
# Loss val: 0.0171
# Iou(Jaccard index) train: 0.8628
# Iou(Jaccard index) val: 0.8306
# ------------
# Model saved with iou_val: 0.8490470895227397
# Epoch 22/30
# ------------
# Loss train: 0.0114
# Loss val: 0.0165
# Iou(Jaccard index) train: 0.8670
# Iou(Jaccard index) val: 0.8490
# ------------
# Epoch 23/30
# ------------
# Loss train: 0.0112
# Loss val: 0.0166
# Iou(Jaccard index) train: 0.8693
# Iou(Jaccard index) val: 0.8483
# ------------
# Model saved with iou_val: 0.8513484422890645
# Epoch 24/30
# ------------
# Loss train: 0.0110
# Loss val: 0.0167
# Iou(Jaccard index) train: 0.8715
# Iou(Jaccard index) val: 0.8513
# ------------
# Epoch 25/30
# ------------
# Loss train: 0.0110
# Loss val: 0.0168
# Iou(Jaccard index) train: 0.8697
# Iou(Jaccard index) val: 0.8480
# ------------
# Epoch 26/30
# ------------
# Loss train: 0.0108
# Loss val: 0.0168
# Iou(Jaccard index) train: 0.8728
# Iou(Jaccard index) val: 0.8494
# ------------
# Model saved with iou_val: 0.8516449900168293
# Epoch 27/30
# ------------
# Loss train: 0.0108
# Loss val: 0.0169
# Iou(Jaccard index) train: 0.8730
# Iou(Jaccard index) val: 0.8516
# ------------
# Model saved with iou_val: 0.8528777585839326
# Epoch 28/30
# ------------
# Loss train: 0.0108
# Loss val: 0.0168
# Iou(Jaccard index) train: 0.8735
# Iou(Jaccard index) val: 0.8529
# ------------
# Epoch 29/30
# ------------
# Loss train: 0.0108
# Loss val: 0.0169
# Iou(Jaccard index) train: 0.8735
# Iou(Jaccard index) val: 0.8489
# ------------
# Epoch 30/30
# ------------
# Loss train: 0.0107
# Loss val: 0.0171
# Iou(Jaccard index) train: 0.8734
# Iou(Jaccard index) val: 0.8500
# ------------

# %% [markdown]
# # **Модель на основе архитектуры DeepLabV3**

# %%
from torchvision.models.segmentation import deeplabv3_resnet50
import torch.optim as optim

# Определение модели
model_deeplabv3 = deeplabv3_resnet50(num_classes=1)

# Изменение количества входных каналов на 1
model_deeplabv3.backbone.conv1 = torch.nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3)

# # Изменение количества выходных каналов на 1
# model_deeplabv3.classifier[-1] = torch.nn.Conv2d(256, 1, kernel_size=1, stride=1)

# Определение функции потерь и оптимизатора
loss_fn = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model_deeplabv3.parameters(), lr=0.001)

# Обучение модели
history_deeplabv3 = train(model = model_deeplabv3,train_dl=train_loader,val_dl=val_loader,num_epochs=30,loss_fn=loss_fn,
                          optimizer=optimizer,name_model='DeepLabV3',use_scheduler=True, access_key=True)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 150MB/s]
# Model saved with iou_val: 0.33062555391411735
# Epoch 1/30
# ------------
# Loss train: 0.0903
# Loss val: 0.0513
# Iou(Jaccard index) train: 0.3911
# Iou(Jaccard index) val: 0.3306
# ------------
# Epoch 2/30
# ------------
# Loss train: 0.0369
# Loss val: 0.0564
# Iou(Jaccard index) train: 0.6047
# Iou(Jaccard index) val: 0.0892
# ------------
# Model saved with iou_val: 0.7389965912081161
# Epoch 3/30
# ------------
# Loss train: 0.0284
# Loss val: 0.0247
# Iou(Jaccard index) train: 0.7035
# Iou(Jaccard index) val: 0.7390
# ------------
# Epoch 4/30
# ------------
# Loss train: 0.0298
# Loss val: 0.0249
# Iou(Jaccard index) train: 0.6788
# Iou(Jaccard index) val: 0.7095
# ------------
# Model saved with iou_val: 0.7627013679945244
# Epoch 5/30
# ------------
# Loss train: 0.0247
# Loss val: 0.0254
# Iou(Jaccard index) train: 0.7387
# Iou(Jaccard index) val: 0.7627
# ------------
# Model saved with iou_val: 0.7699128484950876
# Epoch 6/30
# ------------
# Loss train: 0.0230
# Loss val: 0.0213
# Iou(Jaccard index) train: 0.7542
# Iou(Jaccard index) val: 0.7699
# ------------
# Model saved with iou_val: 0.793607270942544
# Epoch 7/30
# ------------
# Loss train: 0.0199
# Loss val: 0.0216
# Iou(Jaccard index) train: 0.7830
# Iou(Jaccard index) val: 0.7936
# ------------
# Epoch 8/30
# ------------
# Loss train: 0.0194
# Loss val: 0.0187
# Iou(Jaccard index) train: 0.7861
# Iou(Jaccard index) val: 0.7722
# ------------
# Model saved with iou_val: 0.806255228114578
# Epoch 9/30
# ------------
# Loss train: 0.0181
# Loss val: 0.0191
# Iou(Jaccard index) train: 0.7952
# Iou(Jaccard index) val: 0.8063
# ------------
# Epoch 10/30
# ------------
# Loss train: 0.0172
# Loss val: 0.0194
# Iou(Jaccard index) train: 0.8070
# Iou(Jaccard index) val: 0.7812
# ------------
# Model saved with iou_val: 0.8209875079820741
# Epoch 11/30
# ------------
# Loss train: 0.0165
# Loss val: 0.0202
# Iou(Jaccard index) train: 0.8139
# Iou(Jaccard index) val: 0.8210
# ------------
# Epoch 12/30
# ------------
# Loss train: 0.0155
# Loss val: 0.0197
# Iou(Jaccard index) train: 0.8233
# Iou(Jaccard index) val: 0.8010
# ------------
# Model saved with iou_val: 0.8453338927817795
# Epoch 13/30
# ------------
# Loss train: 0.0150
# Loss val: 0.0177
# Iou(Jaccard index) train: 0.8282
# Iou(Jaccard index) val: 0.8453
# ------------
# Epoch 14/30
# ------------
# Loss train: 0.0133
# Loss val: 0.0328
# Iou(Jaccard index) train: 0.8440
# Iou(Jaccard index) val: 0.6911
# ------------
# Epoch 15/30
# ------------
# Loss train: 0.0216
# Loss val: 0.0229
# Iou(Jaccard index) train: 0.7654
# Iou(Jaccard index) val: 0.7332
# ------------
# Epoch 16/30
# ------------
# Loss train: 0.0139
# Loss val: 0.0159
# Iou(Jaccard index) train: 0.8321
# Iou(Jaccard index) val: 0.8151
# ------------
# Epoch 17/30
# ------------
# Loss train: 0.0125
# Loss val: 0.0161
# Iou(Jaccard index) train: 0.8484
# Iou(Jaccard index) val: 0.8183
# ------------
# Epoch 18/30
# ------------
# Loss train: 0.0118
# Loss val: 0.0152
# Iou(Jaccard index) train: 0.8562
# Iou(Jaccard index) val: 0.8409
# ------------
# Model saved with iou_val: 0.8470663810675999
# Epoch 19/30
# ------------
# Loss train: 0.0112
# Loss val: 0.0151
# Iou(Jaccard index) train: 0.8619
# Iou(Jaccard index) val: 0.8471
# ------------
# Epoch 20/30
# ------------
# Loss train: 0.0107
# Loss val: 0.0150
# Iou(Jaccard index) train: 0.8670
# Iou(Jaccard index) val: 0.8467
# ------------
# Model saved with iou_val: 0.8569686109164976
# Epoch 21/30
# ------------
# Loss train: 0.0103
# Loss val: 0.0149
# Iou(Jaccard index) train: 0.8715
# Iou(Jaccard index) val: 0.8570
# ------------
# Model saved with iou_val: 0.8578806570116079
# Epoch 22/30
# ------------
# Loss train: 0.0096
# Loss val: 0.0150
# Iou(Jaccard index) train: 0.8776
# Iou(Jaccard index) val: 0.8579
# ------------
# Epoch 23/30
# ------------
# Loss train: 0.0094
# Loss val: 0.0151
# Iou(Jaccard index) train: 0.8804
# Iou(Jaccard index) val: 0.8565
# ------------
# Model saved with iou_val: 0.8635732970147763
# Epoch 24/30
# ------------
# Loss train: 0.0092
# Loss val: 0.0154
# Iou(Jaccard index) train: 0.8824
# Iou(Jaccard index) val: 0.8636
# ------------
# Epoch 25/30
# ------------
# Loss train: 0.0090
# Loss val: 0.0154
# Iou(Jaccard index) train: 0.8852
# Iou(Jaccard index) val: 0.8556
# ------------
# Epoch 26/30
# ------------
# Loss train: 0.0088
# Loss val: 0.0155
# Iou(Jaccard index) train: 0.8865
# Iou(Jaccard index) val: 0.8618
# ------------
# Epoch 27/30
# ------------
# Loss train: 0.0087
# Loss val: 0.0155
# Iou(Jaccard index) train: 0.8877
# Iou(Jaccard index) val: 0.8611
# ------------
# Epoch 28/30
# ------------
# Loss train: 0.0087
# Loss val: 0.0155
# Iou(Jaccard index) train: 0.8877
# Iou(Jaccard index) val: 0.8608
# ------------
# Model saved with iou_val: 0.8643791315690527
# Epoch 29/30
# ------------
# Loss train: 0.0086
# Loss val: 0.0155
# Iou(Jaccard index) train: 0.8888
# Iou(Jaccard index) val: 0.8644
# ------------
# Epoch 30/30
# ------------
# Loss train: 0.0086
# Loss val: 0.0156
# Iou(Jaccard index) train: 0.8898
# Iou(Jaccard index) val: 0.8624
# ------------

# %% [markdown]
# # **Модель на основе архитектуры Unet от MONAI**

# %%
from monai.networks.nets import Unet
# Out:
# 2024-05-30 15:54:27.894294: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-30 15:54:27.894393: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-30 15:54:28.019068: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
model_unet_monai = Unet(spatial_dims=2,in_channels=1,out_channels=1,channels=(64, 128, 256, 512, 1024),strides=(2,2,2,2))

# Определение функции потерь и оптимизатора
loss_fn = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model_unet_monai.parameters(), lr=0.001)

# Обучение модели
history_unet_monai = train(model = model_unet_monai,train_dl=train_loader,val_dl=val_loader,num_epochs=30,loss_fn=loss_fn,optimizer=optimizer,name_model='U-Net_monai',use_scheduler=True,access_key=False)
# Out:
# Model saved with iou_val: 0.18223842879194976
# Epoch 1/30
# ------------
# Loss train: 0.0990
# Loss val: 0.0555
# Iou(Jaccard index) train: 0.2362
# Iou(Jaccard index) val: 0.1822
# ------------
# Model saved with iou_val: 0.567351261399827
# Epoch 2/30
# ------------
# Loss train: 0.0495
# Loss val: 0.0394
# Iou(Jaccard index) train: 0.4504
# Iou(Jaccard index) val: 0.5674
# ------------
# Model saved with iou_val: 0.6938294692421859
# Epoch 3/30
# ------------
# Loss train: 0.0402
# Loss val: 0.0367
# Iou(Jaccard index) train: 0.5499
# Iou(Jaccard index) val: 0.6938
# ------------
# Epoch 4/30
# ------------
# Loss train: 0.0347
# Loss val: 0.0320
# Iou(Jaccard index) train: 0.6083
# Iou(Jaccard index) val: 0.6407
# ------------
# Epoch 5/30
# ------------
# Loss train: 0.0314
# Loss val: 0.0281
# Iou(Jaccard index) train: 0.6494
# Iou(Jaccard index) val: 0.6828
# ------------
# Epoch 6/30
# ------------
# Loss train: 0.0283
# Loss val: 0.0297
# Iou(Jaccard index) train: 0.6851
# Iou(Jaccard index) val: 0.5490
# ------------
# Epoch 7/30
# ------------
# Loss train: 0.0250
# Loss val: 0.0288
# Iou(Jaccard index) train: 0.7182
# Iou(Jaccard index) val: 0.6004
# ------------
# Model saved with iou_val: 0.7905570611638842
# Epoch 8/30
# ------------
# Loss train: 0.0228
# Loss val: 0.0261
# Iou(Jaccard index) train: 0.7457
# Iou(Jaccard index) val: 0.7906
# ------------
# Epoch 9/30
# ------------
# Loss train: 0.0198
# Loss val: 0.0247
# Iou(Jaccard index) train: 0.7806
# Iou(Jaccard index) val: 0.6993
# ------------
# Epoch 10/30
# ------------
# Loss train: 0.0189
# Loss val: 0.0240
# Iou(Jaccard index) train: 0.7921
# Iou(Jaccard index) val: 0.7315
# ------------
# Epoch 11/30
# ------------
# Loss train: 0.0157
# Loss val: 0.0262
# Iou(Jaccard index) train: 0.8256
# Iou(Jaccard index) val: 0.7029
# ------------
# Epoch 12/30
# ------------
# Loss train: 0.0140
# Loss val: 0.0251
# Iou(Jaccard index) train: 0.8439
# Iou(Jaccard index) val: 0.7322
# ------------
# Model saved with iou_val: 0.8453503318552701
# Epoch 13/30
# ------------
# Loss train: 0.0127
# Loss val: 0.0220
# Iou(Jaccard index) train: 0.8558
# Iou(Jaccard index) val: 0.8454
# ------------
# Epoch 14/30
# ------------
# Loss train: 0.0169
# Loss val: 0.0231
# Iou(Jaccard index) train: 0.8138
# Iou(Jaccard index) val: 0.7876
# ------------
# Epoch 15/30
# ------------
# Loss train: 0.0129
# Loss val: 0.0213
# Iou(Jaccard index) train: 0.8524
# Iou(Jaccard index) val: 0.8303
# ------------
# Epoch 16/30
# ------------
# Loss train: 0.0095
# Loss val: 0.0217
# Iou(Jaccard index) train: 0.8862
# Iou(Jaccard index) val: 0.8221
# ------------
# Epoch 17/30
# ------------
# Loss train: 0.0090
# Loss val: 0.0222
# Iou(Jaccard index) train: 0.8911
# Iou(Jaccard index) val: 0.8311
# ------------
# Epoch 18/30
# ------------
# Loss train: 0.0086
# Loss val: 0.0225
# Iou(Jaccard index) train: 0.8954
# Iou(Jaccard index) val: 0.8287
# ------------
# Epoch 19/30
# ------------
# Loss train: 0.0082
# Loss val: 0.0231
# Iou(Jaccard index) train: 0.8995
# Iou(Jaccard index) val: 0.8392
# ------------
# Epoch 20/30
# ------------
# Loss train: 0.0079
# Loss val: 0.0241
# Iou(Jaccard index) train: 0.9034
# Iou(Jaccard index) val: 0.8359
# ------------
# Epoch 21/30
# ------------
# Loss train: 0.0075
# Loss val: 0.0240
# Iou(Jaccard index) train: 0.9062
# Iou(Jaccard index) val: 0.8450
# ------------
# Epoch 22/30
# ------------
# Loss train: 0.0070
# Loss val: 0.0246
# Iou(Jaccard index) train: 0.9105
# Iou(Jaccard index) val: 0.8433
# ------------
# Model saved with iou_val: 0.8474635110711152
# Epoch 23/30
# ------------
# Loss train: 0.0069
# Loss val: 0.0247
# Iou(Jaccard index) train: 0.9126
# Iou(Jaccard index) val: 0.8475
# ------------
# Epoch 24/30
# ------------
# Loss train: 0.0068
# Loss val: 0.0253
# Iou(Jaccard index) train: 0.9140
# Iou(Jaccard index) val: 0.8431
# ------------
# Epoch 25/30
# ------------
# Loss train: 0.0067
# Loss val: 0.0257
# Iou(Jaccard index) train: 0.9153
# Iou(Jaccard index) val: 0.8439
# ------------
# Epoch 26/30
# ------------
# Loss train: 0.0065
# Loss val: 0.0257
# Iou(Jaccard index) train: 0.9159
# Iou(Jaccard index) val: 0.8454
# ------------
# Epoch 27/30
# ------------
# Loss train: 0.0065
# Loss val: 0.0258
# Iou(Jaccard index) train: 0.9164
# Iou(Jaccard index) val: 0.8447
# ------------
# Epoch 28/30
# ------------
# Loss train: 0.0065
# Loss val: 0.0259
# Iou(Jaccard index) train: 0.9166
# Iou(Jaccard index) val: 0.8464
# ------------
# Epoch 29/30
# ------------
# Loss train: 0.0065
# Loss val: 0.0260
# Iou(Jaccard index) train: 0.9175
# Iou(Jaccard index) val: 0.8466
# ------------
# Epoch 30/30
# ------------
# Loss train: 0.0064
# Loss val: 0.0262
# Iou(Jaccard index) train: 0.9177
# Iou(Jaccard index) val: 0.8445
# ------------

# %% [markdown]
# # **Сравнение моделей**

# %%
plt.figure(figsize=(10,5))
plt.plot(range(1,31),history_unet['epochs loss train'], label='UNet')
plt.plot(range(1,31),history_deeplabv3['epochs loss train'], label='DeepLabv3')
plt.plot(range(1,31),history_unet_monai['epochs loss train'], label='UNet monai')
plt.title('Loss train')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.xticks([1] + [i for i in range(5,31,5)], [1] + [i for i in range(5,31,5)])
plt.legend()

plt.figure(figsize=(10,5))
plt.plot(range(1,31),history_unet['epochs loss val'], label='UNet')
plt.plot(range(1,31),history_deeplabv3['epochs loss val'], label='DeepLabv3')
plt.plot(range(1,31),history_unet_monai['epochs loss val'], label='UNet monai')
plt.title('Loss val')
plt.xlabel('Epochs')
plt.ylabel('log(Loss)')
plt.xticks([1] + [i for i in range(5,31,5)], [1] + [i for i in range(5,31,5)])
plt.yscale('log')
plt.yticks([0.01,0.03,0.1,0.3,1,2],[0.01,0.03,0.1,0.3,1,2])
plt.legend()

plt.figure(figsize=(10,5))
plt.plot(range(1,31),history_unet['iou(Jaccard index) train'], label='UNet')
plt.plot(range(1,31),history_deeplabv3['iou(Jaccard index) train'], label='DeepLabv3')
plt.plot(range(1,31),history_unet_monai['iou(Jaccard index) train'], label='UNet monai')
plt.title('Iou(Jaccard index) train')
plt.xlabel('Epochs')
plt.ylabel('Iou')
plt.xticks([1] + [i for i in range(5,31,5)], [1] + [i for i in range(5,31,5)])
plt.legend()

plt.figure(figsize=(10,5))
plt.plot(range(1,31),history_unet['iou(Jaccard index) val'], label='UNet')
plt.plot(range(1,31),history_deeplabv3['iou(Jaccard index) val'], label='DeepLabv3')
plt.plot(range(1,31),history_unet_monai['iou(Jaccard index) val'], label='UNet monai')
plt.title('Iou(Jaccard index) val')
plt.xlabel('Epochs')
plt.ylabel('Iou')
plt.xticks([1] + [i for i in range(5,31,5)], [1] + [i for i in range(5,31,5)])
plt.legend()

# %%
model_unet.load_state_dict(torch.load('/kaggle/working/best_model_U-Net.pth'))
model_deeplabv3.load_state_dict(torch.load('/kaggle/working/best_model_DeepLabV3.pth'))
model_unet_monai.load_state_dict(torch.load('/kaggle/working/best_model_U-Net_monai.pth'))
# Out:
# <All keys matched successfully>

# %%
model_unet.eval()
model_deeplabv3.eval()
model_unet_monai.eval()

iou_test_unet = []
iou_test_deeplabv3 = []
iou_test_unet_monai = []

for batch in test_loader:
    images, labels = batch
    images, labels = images.to(device), labels
    
    with torch.no_grad():
        out_unet = model_unet(images)['out'].detach().cpu()
        out_deeplabv3 = model_deeplabv3(images)['out'].detach().cpu() 
        out_unet_monai = model_unet_monai(images).detach().cpu()
    
    iou_unet = get_iou(out_unet,labels)
    iou_deeplabv3 = get_iou(out_deeplabv3,labels)
    iou_unet_monai = get_iou(out_unet_monai,labels)
            
    iou_test_unet.append(iou_unet)
    iou_test_deeplabv3.append(iou_deeplabv3)
    iou_test_unet_monai.append(iou_unet_monai)

print('---------------------------------------------------------')
print(f'Iou(Индекс Жакара) для U-Net модели на тестовых данных: {sum(iou_test_unet)/len(iou_test_unet):.4f}')
print('---------------------------------------------------------')
print(f'Iou(Индекс Жакара) для DeeplabV3 модели на тестовых данных: {sum(iou_test_deeplabv3)/len(iou_test_deeplabv3):.4f}')
print('---------------------------------------------------------')
print(f'Iou(Индекс Жакара) для U-Net модели от Monai на тестовых данных: {sum(iou_test_unet_monai)/len(iou_test_unet_monai):.4f}')
print('---------------------------------------------------------')
# Out:
# ---------------------------------------------------------
# Iou(Индекс Жакара) для U-Net модели на тестовых данных: 0.8417
# ---------------------------------------------------------
# Iou(Индекс Жакара) для DeeplabV3 модели на тестовых данных: 0.8549
# ---------------------------------------------------------
# Iou(Индекс Жакара) для U-Net модели от Monai на тестовых данных: 0.8357
# ---------------------------------------------------------

# %%
for batch in test_loader:
    images, labels = batch
    images, labels = images.to(device), labels
            
    with torch.no_grad():
        out_unet = model_unet(images)['out'].detach().cpu()
        out_deeplabv3 = model_deeplabv3(images)['out'].detach().cpu()
        out_unet_monai = model_unet_monai(images).detach().cpu()
        
    break

# %%
images = images.cpu()

fig,axes = plt.subplots(8,5,figsize=(20,30))
fig.tight_layout()
for i in range(len(axes)):
    if i<8:
        axes[i][0].imshow(images[i].squeeze(0), cmap='gray')
        axes[i][0].set_title('Оригинальное изображение')
        axes[i][0].axis('off')

        axes[i][1].imshow(labels[i].squeeze(0), cmap='gray')
        axes[i][1].set_title('Маска')
        axes[i][1].axis('off')

        axes[i][2].imshow(torch.sigmoid(out_deeplabv3[i].squeeze(0)) > 0.7, cmap='gray')
        axes[i][2].set_title('Предсказание DeeplabV3')
        axes[i][2].axis('off')

        axes[i][3].imshow(torch.sigmoid(out_unet[i].squeeze(0)) > 0.7, cmap='gray')
        axes[i][3].set_title('Предсказание Unet с нуля')
        axes[i][3].axis('off')
        
        axes[i][4].imshow(torch.sigmoid(out_unet_monai[i].squeeze(0)) > 0.7, cmap='gray')
        axes[i][4].set_title('Предсказание Unet monai')
        axes[i][4].axis('off')

# %% [markdown]
# # **Recall,Precision,F1 score**

# %%
def get_recall(out,labels):
    out = torch.sigmoid(out) > 0.9
    out = out.squeeze(1)
    labels = labels.squeeze(1)
    
    tp = torch.logical_and(out,labels).sum().float()
    fn = torch.logical_and(~out, labels).sum().float()
    
    recall = tp/(tp+fn)
    
    return recall.mean().item()

def get_precision(out,labels):
    out = torch.sigmoid(out) > 0.9
    out = out.squeeze(1)
    labels = labels.squeeze(1)
    
    tp = torch.logical_and(out,labels).sum().float()
    fp = torch.logical_and(out, ~(labels.int())).sum().float()
    
    precision = tp/(tp+fp)
    
    return precision.mean().item()

def get_f1_score(out,labels):
    
    recall = get_recall(out,labels)
    precision = get_precision(out,labels)
    
    f1_score = 2*precision*recall/(precision+recall)
    
    return f1_score

# %%
model_unet.eval()
model_deeplabv3.eval()
model_unet_monai.eval()

recall_test_unet = []
recall_test_deeplabv3 = []
recall_test_unet_monai = []

precision_test_unet = []
precision_test_deeplabv3 = []
precision_test_unet_monai = []

f1_score_test_unet = []
f1_score_test_deeplabv3 = []
f1_score_test_unet_monai = []

for batch in test_loader:
    images, labels = batch
    images, labels = images.to(device), labels
    
    with torch.no_grad():
        out_unet = model_unet(images)['out'].detach().cpu()
        out_deeplabv3 = model_deeplabv3(images)['out'].detach().cpu() 
        out_unet_monai = model_unet_monai(images).detach().cpu()
    
    recall_unet = get_recall(out_unet,labels)
    recall_deeplabv3 = get_recall(out_deeplabv3,labels)
    recall_unet_monai = get_recall(out_unet_monai,labels)
    
    precision_unet = get_precision(out_unet,labels)
    precision_deeplabv3 = get_precision(out_deeplabv3,labels)
    precision_unet_monai = get_precision(out_unet_monai,labels)
    
    f1_score_unet = get_f1_score(out_unet,labels)
    f1_score_deeplabv3 = get_f1_score(out_deeplabv3,labels)
    f1_score_unet_monai = get_f1_score(out_unet_monai,labels)
            
    recall_test_unet.append(recall_unet)
    recall_test_deeplabv3.append(recall_deeplabv3)
    recall_test_unet_monai.append(recall_unet_monai)

    precision_test_unet.append(precision_unet)
    precision_test_deeplabv3.append(precision_deeplabv3)
    precision_test_unet_monai.append(precision_unet_monai)

    f1_score_test_unet.append(f1_score_unet)
    f1_score_test_deeplabv3.append(f1_score_deeplabv3)
    f1_score_test_unet_monai.append(f1_score_unet_monai)

print('---------------------------------------------------------')
print(f'Recall для U-Net модели на тестовых данных: {sum(recall_test_unet)/len(recall_test_unet)}')
print('---------------------------------------------------------')
print(f'Recall для DeeplabV3 модели на тестовых данных: {sum(recall_test_deeplabv3)/len(recall_test_deeplabv3):.4f}')
print('---------------------------------------------------------')
print(f'Recall для U-Net модели от Monai на тестовых данных: {sum(recall_test_unet_monai)/len(recall_test_unet_monai):.4f}')
print('---------------------------------------------------------')

print('---------------------------------------------------------')
print(f'Precision для U-Net модели на тестовых данных: {sum(precision_test_unet)/len(precision_test_unet):.4f}')
print('---------------------------------------------------------')
print(f'Precision для DeeplabV3 модели на тестовых данных: {sum(precision_test_deeplabv3)/len(precision_test_deeplabv3):.4f}')
print('---------------------------------------------------------')
print(f'Precision для U-Net модели от Monai на тестовых данных: {sum(precision_test_unet_monai)/len(precision_test_unet_monai):.4f}')
print('---------------------------------------------------------')

print('---------------------------------------------------------')
print(f'F1 score для U-Net модели на тестовых данных: {sum(f1_score_test_unet)/len(f1_score_test_unet):.4f}')
print('---------------------------------------------------------')
print(f'F1 score для DeeplabV3 модели на тестовых данных: {sum(f1_score_test_deeplabv3)/len(f1_score_test_deeplabv3):.4f}')
print('---------------------------------------------------------')
print(f'F1 score для U-Net модели от Monai на тестовых данных: {sum(f1_score_test_unet_monai)/len(f1_score_test_unet_monai):.4f}')
print('---------------------------------------------------------')
# Out:
# ---------------------------------------------------------
# Recall для U-Net модели на тестовых данных: 0.8533243936187817
# ---------------------------------------------------------
# Recall для DeeplabV3 модели на тестовых данных: 0.8658
# ---------------------------------------------------------
# Recall для U-Net модели от Monai на тестовых данных: 0.8553
# ---------------------------------------------------------
# ---------------------------------------------------------
# Precision для U-Net модели на тестовых данных: 0.4959
# ---------------------------------------------------------
# Precision для DeeplabV3 модели на тестовых данных: 0.4963
# ---------------------------------------------------------
# Precision для U-Net модели от Monai на тестовых данных: 0.4932
# ---------------------------------------------------------
# ---------------------------------------------------------
# F1 score для U-Net модели на тестовых данных: 0.6269
# ---------------------------------------------------------
# F1 score для DeeplabV3 модели на тестовых данных: 0.6307
# ---------------------------------------------------------
# F1 score для U-Net модели от Monai на тестовых данных: 0.6253
# ---------------------------------------------------------
